# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
df = pd.read_csv('../data/melb_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
average_land_size = df['Landsize'].mean()
average_land_size
# Out:
# np.float64(558.4161266568483)

# %%
np.floor(average_land_size)
# Out:
# np.float64(558.0)

# %%
# how old is the newest house?
newest_house = df['YearBuilt'].max()
newest_house
# Out:
# np.float64(2018.0)

# %%
from datetime import datetime
min_house_age = datetime.now().year - newest_house
min_house_age
# Out:
# np.float64(7.0)

# %% [markdown]
# ### Data Cleaning

# %%
# null, missing values, duplicates, outliers, data types

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
cdf = df.copy()

# %%
cdf.drop(columns =['BuildingArea'], inplace=True, axis=1)

# %%
cdf
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
corr_matrix = cdf.corr(numeric_only=True)

# %%
corr_matrix
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# Propertycount -0.081530 -0.042153 -0.054910  0.062304 -0.081350 -0.052201
#
# ...

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %% [markdown]
# ### Selecting Target and Fetures

# %%
# our target variable is price

y = df.Price

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
features = ['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'YearBuilt']

# %%
# features variable
X = df[features]

# %%
X.corr()
# Out:
#               Rooms  Distance  Bedroom2  Bathroom       Car  Landsize  \
# Rooms      1.000000  0.294203  0.944190  0.592934  0.408483  0.025678
# Distance   0.294203  1.000000  0.295927  0.127155  0.262994  0.025004
# Bedroom2   0.944190  0.295927  1.000000  0.584685  0.405325  0.025646
# Bathroom   0.592934  0.127155  0.584685  1.000000  0.322246  0.037130
# Car        0.408483  0.262994  0.405325  0.322246  1.000000  0.026770
# Landsize   0.025678  0.025004  0.025646  0.037130  0.026770  1.000000
# YearBuilt -0.065413  0.246379 -0.053319  0.152702  0.104515  0.036451
#
#            YearBuilt
# Rooms      -0.065413
# Distance    0.246379
# Bedroom2   -0.053319
# Bathroom    0.152702
# Car         0.104515
# Landsize    0.036451
# YearBuilt   1.000000

# %% [markdown]
# ### Build a model

# %%
# importing scikit-learn
from sklearn.tree import DecisionTreeRegressor

# %%
# building the model
house_model = DecisionTreeRegressor(random_state=1)

# %%
# fit the data into the model
house_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# making predictions
X.head()
# Out:
#    Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  YearBuilt
# 0      2       2.5       2.0       1.0  1.0     202.0        NaN
# 1      2       2.5       2.0       1.0  0.0     156.0     1900.0
# 2      3       2.5       3.0       2.0  0.0     134.0     1900.0
# 3      3       2.5       3.0       2.0  1.0      94.0        NaN
# 4      4       2.5       3.0       1.0  2.0     120.0     2014.0

# %%
house_model.predict(X.head())
# Out:
# array([1480000., 1035000., 1465000.,  850000., 1600000.])

# %%
df['Price'].head()
# Out:
# 0    1480000.0
# 1    1035000.0
# 2    1465000.0
# 3     850000.0
# 4    1600000.0
# Name: Price, dtype: float64

# %%
# using train test split method

from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

# %%
house_model_new = DecisionTreeRegressor()

# %%
house_model_new.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor()

# %%
# testing the model
house_model_new.predict(train_X.head())
# Out:
# array([1335000.,  590000., 1420000.,  528000., 1830000.])

# %%
train_y.head()
# Out:
# 664      1335000.0
# 3270      590000.0
# 3873     1420000.0
# 13170     552500.0
# 1730     1830000.0
# Name: Price, dtype: float64

# %%
# predicting the test data
predicted_on_test = house_model_new.predict(test_X.head())
predicted_on_test
# Out:
# array([1805000.,  887000.,  660000., 1100000.,  629000.])

# %%
test_y.head()
# Out:
# 8505     2165000.0
# 5523      815000.0
# 12852     610000.0
# 4818     1245000.0
# 12812    1160000.0
# Name: Price, dtype: float64

# %%
# evaluating the model performance
# Mean Absolute Error (MAE)

from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test_y, house_model_new.predict(test_X))
# Out:
# 322399.3140728456

# %%
# Mean Squared Error (MSE)

from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(test_y, house_model_new.predict(test_X))
# Out:
# 296682487051.3389

# %%
# Root Mean Squared Error (RMSE)

from sklearn.metrics import root_mean_squared_error

# %%
root_mean_squared_error(test_y, house_model_new.predict(test_X))
# Out:
# 544685.6772959419

# %%
# R2 Score
from sklearn.metrics import r2_score

# %%
r2_score(test_y, house_model_new.predict(test_X))
# Out:
# 0.29965694827902667

# %%
# Trying the new algorithm
# Random Forest Regressor

from sklearn.ensemble import RandomForestRegressor

# %%
forest_model = RandomForestRegressor(random_state=1)

# %%
# fitting the data into the model

forest_model.fit(train_X, train_y)
# Out:
# RandomForestRegressor(random_state=1)

# %%
hp3 = forest_model.predict(test_X)

# %%
hp3
# Out:
# array([1548940.        ,  943850.        ,  784350.        , ...,
#        1072231.48      ,  749958.33333333, 1072535.        ],
#       shape=(3395,))

# %%
test_y
# Out:
# 8505     2165000.0
# 5523      815000.0
# 12852     610000.0
# 4818     1245000.0
# 12812    1160000.0
#            ...
# 12961     875000.0
# 2572     1286000.0
# 9503      885000.0
# 356       487500.0
# 2034     1194500.0
# Name: Price, Length: 3395, dtype: float64

# %%
mean_absolute_error(test_y, hp3)
# Out:
# 250020.66760429903

# %%
root_mean_squared_error(test_y, hp3)
# Out:
# 412665.98614941264

# %%
# features = [ 'Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'YearBuilt']

# predicting the price of a new house
house_new = [4, 150, 3, 3, 2, 400, 2017]

house_new_df = pd.DataFrame(house_new).T
house_new_df.columns = features
house_new_df
# Out:
#    Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  YearBuilt
# 0      4       150         3         3    2       400       2017

# %%
# predicting the price of the new house using Decision Tree Regressor
house_model_new.predict(house_new_df)
# Out:
# array([559000.])

# %%
# predicting the price of the new house using Random Forest Regressor
forest_model.predict(house_new_df)
# Out:
# array([664910.72])
