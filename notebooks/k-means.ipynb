# %% [markdown]
# ## Unsupervised Machine Learning

# %% [markdown]
# # 🤖 Unsupervised Machine Learning
#
# ## 📌 What is Unsupervised Learning?
# Unsupervised Machine Learning is a type of ML where the model **learns patterns from unlabeled data** without predefined outputs.
#
# ## 🔹 Key Features:
# - No labeled data required.
# - Identifies hidden structures and relationships in data.
# - Used for clustering, association, and dimensionality reduction.
#
# ## 📊 Common Types:
# ### 1️⃣ **Clustering** 🏷️
#    - Groups similar data points together.
#    - Example: **K-Means, DBSCAN, Hierarchical Clustering**
#    - **Use Case:** Customer segmentation in marketing.
#
# ### 2️⃣ **Dimensionality Reduction** 📉
#    - Reduces data size while preserving important features.
#    - Example: **PCA (Principal Component Analysis), t-SNE**
#    - **Use Case:** Image compression, data visualization.
#
# ### 3️⃣ **Association Rule Learning** 🔗
#    - Discovers relationships between variables.
#    - Example: **Apriori, FP-Growth**
#    - **Use Case:** Market basket analysis (e.g., "People who buy bread also buy butter").
#
# ## 🛠️ Example Applications:
# - **Anomaly Detection** (e.g., Fraud detection)
# - **Image Segmentation** (e.g., Object detection in images)
# - **Document Clustering** (e.g., Topic modeling for news articles)
#
# ## ⚡ Advantages:
# ✔️ Can handle large amounts of data.
# ✔️ Finds hidden patterns without human intervention.
# ✔️ Helps in exploratory data analysis.
#
# ## ❌ Challenges:
# ❌ Hard to evaluate accuracy (no labeled data).
# ❌ Can be sensitive to hyperparameters.
# ❌ May not always provide meaningful insights.
#
# ---
#
# 💡 **Conclusion:**
# Unsupervised ML is **powerful for discovering hidden insights** from data, making it essential for pattern recognition, clustering, and exploratory analysis. 🚀

# %% [markdown]
# # 🔍 Difference Between Supervised and Unsupervised Machine Learning
#
# | Feature               | Supervised Learning 🏫 | Unsupervised Learning 🤖 |
# |----------------------|--------------------|----------------------|
# | **Definition**        | Learns from labeled data (input-output pairs) | Learns from unlabeled data, finding patterns |
# | **Output**           | Predicts known outcomes (classification/regression) | Finds hidden structures (clustering, association) |
# | **Example Algorithms** | Linear Regression, KNN, Decision Trees, SVM | K-Means, DBSCAN, PCA, Autoencoders |
# | **Example Use Cases** | Spam detection, Disease prediction, Stock price forecasting | Customer segmentation, Anomaly detection, Market basket analysis |
# | **Dependency on Labels** | Requires labeled data for training | No labeled data needed |
# | **Complexity**       | Easier to interpret | Harder to interpret (no predefined labels) |
# | **Real-world Examples** | Email spam detection (Spam/Not Spam) | Grouping customers based on shopping behavior |

# %%
# 1️⃣ Which of the following best describes supervised learning?
# A) The model learns from labeled data
# B) The model finds hidden patterns in data
# C) The model clusters data into groups
# D) The model does not require a target variable

# %%
# 2️⃣ Which of the following is an example of supervised learning?
# A) Customer segmentation
# B) Predicting house prices based on past sales
# C) Market basket analysis
# D) Dimensionality reduction

# %%
# 3️⃣ What is the primary difference between supervised and unsupervised learning?
# A) Supervised learning is more complex
# B) Supervised learning uses labeled data, while unsupervised learning does not
# C) Supervised learning requires more data
# D) Unsupervised learning is always more accurate

# %%
# 4️⃣ Which of the following is a common application of unsupervised learning?
# A) Email spam detection
# B) Fraud detection using anomaly detection
# C) Stock price prediction
# # D) Weather forecasting

# %%
# 5️⃣ Which supervised learning algorithm is best suited for classification tasks?
# A) K-Means Clustering
# B) Principal Component Analysis (PCA)
# C) K-Nearest Neighbors (KNN)
# D) DBSCAN

# %%
# 6️⃣ What is the goal of clustering in unsupervised learning?
# A) To find relationships between features
# B) To predict future values
# C) To group similar data points together
# D) To reduce dataset size

# %%
# 7️⃣ Which of the following algorithms is used for clustering?
# A) Decision Trees
# B) K-Means
# C) Linear Regression
# D) Random Forest

# %%
# 8️⃣ What is the primary purpose of Principal Component Analysis (PCA)?
# A) To classify data into predefined categories
# B) To reduce the dimensionality of a dataset
# C) To detect fraud in transactions
# D) To label images automatically

# %%
# 9️⃣ Which of the following is an example of an unsupervised learning problem?
# A) Predicting diabetes based on patient history
# B) Recommending movies based on similar user preferences
# C) Predicting customer churn in a telecom company
# D) Detecting spam emails

# %%
# 🔟 What is a major limitation of unsupervised learning?
# A) It requires labeled data
# B) It cannot be used for large datasets
# C) It is difficult to evaluate the accuracy of the model
# D) It is not used in real-world applications

# %% [markdown]
# # 🔍 Clustering and Dimensionality Reduction in Machine Learning
#
# ## 📌 1. What is Clustering?
# Clustering is an **unsupervised learning** technique that groups similar data points together **without labeled outputs**.
#
# ### 🔹 Key Features:
# - Finds **hidden patterns** in data.
# - Groups data points based on **similarity**.
# - Used for **customer segmentation, anomaly detection**, etc.
#
# ### 🛠️ Common Clustering Algorithms:
# 1. **K-Means Clustering** – Divides data into **K clusters** using centroid-based grouping.
# 2. **Hierarchical Clustering** – Builds a **tree of clusters** (dendrogram).
# 3. **DBSCAN (Density-Based Clustering)** – Groups **dense areas** and detects anomalies.
#
# ### 📊 Example Use Cases:
# ✔ **Customer Segmentation** – Grouping shoppers based on buying patterns.
# ✔ **Image Segmentation** – Identifying objects in images.
# ✔ **Anomaly Detection** – Detecting fraud in transactions.
#
# ---
#
# ## 📌 2. What is Dimensionality Reduction?
# Dimensionality reduction is a technique used to **reduce the number of input features** while retaining essential information.
#
# ### 🔹 Why Use Dimensionality Reduction?
# - **Reduces computational cost** for large datasets.
# - **Removes noise and redundancy** from data.
# - **Improves model performance** by avoiding the "curse of dimensionality."
#
# ### 🛠️ Common Dimensionality Reduction Techniques:
# 1. **Principal Component Analysis (PCA)** – Converts high-dimensional data into a lower-dimensional space while preserving variance.
# 2. **t-SNE (t-Distributed Stochastic Neighbor Embedding)** – Used for **visualizing high-dimensional data** in 2D/3D.
# 3. **LDA (Linear Discriminant Analysis)** – Used for **supervised dimensionality reduction** to maximize class separability.
#
# ### 📊 Example Use Cases:
# ✔ **Data Visualization** – Reducing 100D data to 2D for plotting.
# ✔ **Image Compression** – Removing redundant pixel information.
# ✔ **Speeding Up Machine Learning Models** – Faster training time with fewer features.
#
# ---
#
# ## 🔥 Key Differences: Clustering vs. Dimensionality Reduction
#
# | Feature              | Clustering 🏷️ | Dimensionality Reduction 📉 |
# |---------------------|-------------|--------------------------|
# | **Goal**            | Group similar data points | Reduce feature count while retaining info |
# | **Type of ML**      | Unsupervised Learning | Can be used in both Supervised & Unsupervised ML |
# | **Examples**        | K-Means, DBSCAN, Hierarchical Clustering | PCA, t-SNE, LDA |
# | **Use Case**        | Customer segmentation, fraud detection | Image compression, feature selection |
#
# ---
#
# 💡 **Conclusion:**
# - **Clustering** is used for **grouping similar data** without labels.
# - **Dimensionality Reduction** is used for **simplifying data** while keeping essential information.
# - Both help in **handling large datasets efficiently** in machine learning. 🚀

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#read dataset
df= pd.read_csv('../data/live.csv')

# %%
df
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 0             1       video   4/22/2018 6:00            529           512
# 1             2       photo  4/21/2018 22:45            150             0
# 2             3       video   4/21/2018 6:17            227           236
# 3             4       photo   4/21/2018 2:29            111             0
# 4             5       photo   4/18/2018 3:22            213             0
# ...         ...         ...              ...            ...           ...
# 7045       7046       photo   9/24/2016 2:58             89             0
# 7046       7047       photo  9/23/2016 11:19             16             0
# 7047       7048       photo  9/21/2016 23:03              2             0
# 7048       7049       photo   9/20/2016 0:43            351            12
# 7049       7050       photo  9/10/2016 10:30             17             0
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# ...

# %%
df.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   int64
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.isna().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.drop(['Column1', 'Column2', 'Column3', 'Column4'], axis= 1, inplace= True)

# %%
df.head()
# Out:
#    status_id status_type status_published  num_reactions  num_comments  \
# 0          1       video   4/22/2018 6:00            529           512
# 1          2       photo  4/21/2018 22:45            150             0
# 2          3       video   4/21/2018 6:17            227           236
# 3          4       photo   4/21/2018 2:29            111             0
# 4          5       photo   4/18/2018 3:22            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0         262        432         92         3          1         1           0
# 1           0        150          0         0          0         0           0
# 2          57        204         21         1          1         0           0
# 3           0        111          0         0          0         0           0
# 4           0        204          9         0          0         0           0

# %%
df['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
df.drop(['status_id', 'status_published'], axis= 1, inplace= True)

# %%
df.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
features= ['num_reactions',
       'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
       'num_hahas', 'num_sads', 'num_angrys']

# %%
# features and target
X= df[features]
y= df['status_type']

# %%
# now we need to transform status_type categorical varibale to numerical label
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
le= LabelEncoder()
y= le.fit_transform(y)

# %%
y
# Out:
# array([3, 1, 3, ..., 1, 1, 1], shape=(7050,))

# %%
X
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               529           512         262        432         92         3
# 1               150             0           0        150          0         0
# 2               227           236          57        204         21         1
# 3               111             0           0        111          0         0
# 4               213             0           0        204          9         0
# ...             ...           ...         ...        ...        ...       ...
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
# ...

# %%
ms= MinMaxScaler()
X= ms.fit_transform(X)
X= pd.DataFrame(X, columns=features)

# %%
X
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0          0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1          0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2          0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3          0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4          0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
# ...             ...           ...         ...        ...        ...       ...
# 7045       0.018896      0.000000    0.000000   0.018896   0.000000  0.000000
# 7046       0.003397      0.000000    0.000000   0.002972   0.001522  0.000000
# 7047       0.000425      0.000000    0.000000   0.000212   0.001522  0.000000
# 7048       0.074522      0.000572    0.006425   0.074098   0.003044  0.000000
# 7049       0.003609      0.000000    0.000000   0.003609   0.000000  0.000000
#
# ...

# %%
#initialize k means clustering 
from sklearn.cluster import KMeans

# %%
# create a kmeans model 
kmeans= KMeans(n_clusters= 3, random_state= 42)

# %%
kmeans
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
kmeans.inertia_
# Out:
# 76.02453718052367

# %%
# evaluate clustering using silhouette_score 
from sklearn.metrics import silhouette_score

# %%
silhouette_avg= silhouette_score(X, kmeans.labels_)

# %%
silhouette_avg
# Out:
# np.float64(0.819291351846674)

# %%
#silhouette score visualization
# Number of clusters
from sklearn.metrics import silhouette_samples, silhouette_score
silhouette_vals = silhouette_samples(X, kmeans.labels_)

n_clusters = kmeans.n_clusters

# Create a figure
plt.figure(figsize=(10, 6))

y_lower = 10
for i in range(n_clusters):
    # Aggregate the silhouette scores for samples in cluster i
    ith_cluster_silhouette_vals = silhouette_vals[kmeans.labels_ == i]
    ith_cluster_silhouette_vals.sort()

    # Compute the size of the cluster
    size_cluster_i = ith_cluster_silhouette_vals.shape[0]
    y_upper = y_lower + size_cluster_i

    # Fill the silhouette plot for the cluster
    plt.fill_betweenx(
        np.arange(y_lower, y_upper),
        0,
        ith_cluster_silhouette_vals,
        alpha=0.7,
        label=f'Cluster {i + 1}'
    )

    # Label the silhouette scores
    plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i + 1))
    y_lower = y_upper + 10  # 10 for the 0 samples gap between clusters

# Vertical line for the average silhouette score
plt.axvline(x=silhouette_avg, color="red", linestyle="--", label="Average Silhouette")

# Plot labels
plt.title("Silhouette Plot for K-Means Clustering", fontsize=15)
plt.xlabel("Silhouette Coefficient Values")
plt.ylabel("Cluster Label")
plt.legend()
plt.show()

# %%
# visualizing using PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
data_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(8,5))
plt.scatter(data_pca[:,0], data_pca[:,1], c=kmeans.labels_, cmap='viridis', s=50, alpha=0.5)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('K-Means Clustering')
plt.show()

# %%
# visualizing in 3D
from mpl_toolkits.mplot3d import Axes3D
pca = PCA(n_components=3)
data_pca3 = pca.fit_transform(X)

pca3_df = pd.DataFrame(data_pca3, columns=['PCA1', 'PCA2', 'PCA3'])

import plotly.express as px
fig = px.scatter_3d(pca3_df, x='PCA1', y='PCA2', z='PCA3', title='K-Means Clustering', color=kmeans.labels_, opacity=0.7, size_max=10)
fig.show()

# %%
pca3_df['Status_type'] = le.inverse_transform(y)
pca3_df['Cluster'] = kmeans.labels_
fig = px.scatter_3d(pca3_df, x='PCA1', y='PCA2', z='PCA3', title='Clustering with status type', color='Cluster', symbol='Status_type', opacity=0.7, size_max=10, hover_data={'Cluster': True, 'Status_type': True})
fig.show()

# %%
# Clustering in 4 clusters
pca = PCA(n_components=4)
data_pca4 = pca.fit_transform(X)
pca4_df = pd.DataFrame(data_pca4, columns=['PCA1', 'PCA2', 'PCA3', 'PCA4'])
pca4_df['Cluster'] = kmeans.labels_
fig = px.scatter_3d(pca4_df, x='PCA1', y='PCA2', z='PCA3', title='Clustering with status type', color='Cluster', opacity=0.7, size_max=10, hover_data={'Cluster': True})
fig.show()

# %%
# Cluster assignment for new data
new_data = [[200, 190, 22, 195, 3, 1, 1, 1, 0]]
new_data = pd.DataFrame(new_data, columns=features)
new_data_scaled = ms.transform(new_data)

# %%
new_data_scaled
# Out:
# array([[0.04246285, 0.00905193, 0.00642523, 0.04140127, 0.00456621,
#         0.00359712, 0.00636943, 0.01960784, 0.        ]])

# %%
cluster_assignment = kmeans.predict(new_data)

# %%
cluster_assignment[0]
# Out:
# np.int32(2)
